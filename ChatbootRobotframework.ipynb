# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamD2022/Teste-Projetos/blob/main/ChatbootRobotframework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q google-generativeai

# %%
import numpy as np
import pandas as pd
import google.generativeai as genai

GOOGLE_API_KEY="AIzaSyAEaP8CvnIb2e0ZVeVfFNczt8qsUmvxr7s"
genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'embedContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %%
text = "william"
result = genai.embed_content(model="models/embedding-001", content=text)

print(result['embedding'])
# Out:
# [0.046729334, -0.048741676, -0.021068174, -0.060283966, 0.052139, 0.012365587, -0.0073639667, 0.001602475, 0.034903, 0.013609098, 0.012918469, 0.009113034, 0.012244937, -0.009277484, 0.02117377, -0.00024703372, 0.028350249, 0.053165983, 0.0030782903, -0.018023288, -0.024528947, 0.04494655, 0.012840278, -0.006909469, -0.0013267733, -0.028436614, 0.019463435, -0.0907062, -0.03304782, 0.058843628, -0.04451133, 0.015007823, -0.042713378, -0.013903377, -0.014961221, -0.0035965377, 0.0060372623, 0.03545121, 0.005696837, -0.024521433, -0.0050765374, -0.029368134, -0.012423486, -0.0034702695, 0.07526035, -0.031120013, 0.045779444, 0.027848179, 0.015514921, -0.08805686, 0.058789317, -0.016731877, 0.01897956, -0.07768195, 0.022624785, -0.014891385, 0.06426253, 0.041518968, -0.091098145, -0.021359878, 0.005450183, 0.042787775, -0.051844206, 0.028753398, 0.018772775, -0.012080787, -0.025902595, 0.052565105, 0.021089936, -0.014191121, -0.017811034, 0.006249254, 0.043418948, -0.012397681, 0.005846
# ...

# %%
result = genai.embed_content(
   model = "models/embedding-001",
   content=[
       'você conhece robootframework?',
       'como funciona robootframework ?',
       'como funciona robootframework?'])


for embedding in result['embedding']:
  print(str(embedding)[:50], '... TRIMMEND]')
# Out:
# [0.017990783, -0.051368494, -0.04088495, -0.004198 ... TRIMMEND]
# [0.025814125, -0.04577916, -0.03784994, 0.02577493 ... TRIMMEND]
# [0.024312304, -0.049265996, -0.038328588, 0.026001 ... TRIMMEND]

# %%
#Exemplo de embedding
title = "tudo sobre robot frame work"
sample_text = ("Título: robotframework"
    "\n"
    "Artigo completo:\n"
    "\n"
    "robot frame work sua automação mais facil")

embeddings = genai.embed_content(model="models/embedding-001",
                                 content=sample_text,
                                 title=title,
                                 task_type="RETRIEVAL_DOCUMENT")

print(embeddings)
# Out:
# {'embedding': [0.045069832, -0.07628506, -0.008365037, 0.0059256665, 0.01658116, 0.022987766, -0.036887825, -0.02485206, 0.034182075, 0.060402088, -0.017094705, -0.0151135335, -0.019098569, -0.010470538, -0.0038336935, -0.014467437, 0.012650137, 0.042198714, -0.03644204, -0.0046222736, 0.025298223, 0.004215234, -0.027096802, -0.07656521, -0.0120988265, -0.023674337, -0.016986039, -0.021978317, -0.00967533, 0.025640786, -0.05089697, -0.0010957345, -0.05108644, 0.020592611, -0.0021274579, -0.013031665, -0.022995682, 0.0475538, -0.010697237, 0.0046496606, -0.00554922, -0.018744478, -0.02654697, -0.026736962, 0.018016823, -0.05773825, -0.0099217985, 0.04296869, 0.0034206496, -0.064503506, -0.0248933, -0.012396667, 0.06554329, 0.0326605, -0.0033463063, -0.015692435, 0.055104855, -0.06502033, -0.022280062, -0.044914294, 0.007943986, 0.058482636, -0.0047504823, 0.050260182, 0.0011479593, -0.030989397, -0.009783685, 0.018943302, 0.019094823, 0.014043344, -0.03827917, -0.04030889, 0.00313824,
# ...

# %%
#Listagem de documentos que serão buscados
DOCUMENT1 = {
     "Título": "como instalar python ",
     "Conteúdo":"entre no site https://python.org.br/instalacao-windows/, faça donwloa Faça o download do instalador executável do Windows (32 ou 64 bits) e clique duas vezes nele para iniciar o assistente de instalação do python, como mostrado abaixo. O processo de instalação é bem simples.Marque a opção Add Python to PATH Clique em Install Now A tela abaixo será mostrada. Aguarde enquanto o instalador completa o processo de instalação.",
     "Conteúdo":"Se tudo ocorrer bem, a próxima tela será mostrada. Clique em Close.",
     "Conteúdo":"Para verificar se a instalação do Python foi bem-sucedida, pesquise no menu iniciar por cmd e clique duas vezes para abri-lo.",
         }

DOCUMENT2 = {
    "Título": "como instalar robot",
    "Conteúdo": "Instalar o Robot Framework com pip é simples:pip install robotframework, Para verificar se a instalação foi bem-sucedida, execute: robot --version, Para obter um guia completo, consulte Instruções de instalação. Ele também cobre tópicos como a execução do Robot Framework no Jython (JVM) e no IronPython (.NET).Agora você está pronto para escrever seus primeiros testes!"

    }

DOCUMENT3 = {
    "Título": "como eu consigo ver as bibliotecas do robotframe work",
    "Conteúdo": "para acessa sua biblioteca voce precisa acessar o link: https://robotframework.org/robotframework/latest/RobotFrameworkUserGuide.html#creating-test-libraries"}

DOCUMENT4 = {
    "Título": "como usar palavras chaves roobotframework",
     "Conteúdo":"Tanto as palavras-chave do usuário quanto as palavras-chave da biblioteca podem ter tags. Da mesma forma que ao marcar casos de teste, há duas configurações que afetam as tags de palavra-chave do usuário:"
    }



DOCUMENT5 = {
        "Título": "o que é robot framework",
        "Conteúdo": "Robot Framework é uma estrutura de automação de código aberto para automação de testes e automação de processos robóticos (RPA). É suportado pela Robot Framework Foundation e amplamente utilizado na indústria."}




DOCUMENT6 = {
        "Título": "como usar arquivo de saida json no robotframework",
        "Conteúdo": "Rebot pode criar e processar arquivos de saída também no formato JSON. A criação de arquivos de saída JSON é feita usando a opção normal --output para que o arquivo especificado tenha uma extensão .json:",
        "Conteúdo": "rebot --output output.json output.xml",
        "Conteúdo":"Ao ler arquivos de saída, os arquivos JSON são reconhecidos automaticamente por A extensão:",
        "Conteúdo":"rebot output.json,rebot output1.json output2.json",
        "Conteúdo":"Ao combinar ou mesclar resultados, é possível misturar arquivos JSON e XML: rebot output1.xml output2.json , rebot --merge original.xml rerun.json ",
        "Conteúdo": "A estrutura do arquivo de saída JSON está documentada no arquivo de esquema result.json."



}

DOCUMENT7= {
        "Título": "Qual melhor site para aprender sobre RobotFrame Work",
        "Conteúdo": "acesse alura, garanto que você vai aprenser muito lá,https://www.alura.com.br/conteudo/robot-framework-testes-padrao-bdd "}




DOCUMENT8= {
        "Título": "Qual a Melhor faculdade e plataforama que eu possa estudar e fazer cursos de IA",
        "Conteúdo": "esta é muito facil acess Fiap e Alura voce vai ser dar muito bem  segue os links, https://www.alura.com.br/, https://www.fiap.com.br/  "}






documents = [DOCUMENT1, DOCUMENT2, DOCUMENT3,DOCUMENT4,DOCUMENT5,DOCUMENT6,DOCUMENT7,DOCUMENT8]

# %%
df = pd.DataFrame(documents)
df.columns = ["Titulo", "Conteudo"]
df
# Out:
#                                               Titulo  \
# 0                              como instalar python
# 1                                como instalar robot
# 2  como eu consigo ver as bibliotecas do robotfra...
# 3          como usar palavras chaves roobotframework
# 4                            o que é robot framework
# 5  como usar arquivo de saida json no robotframework
# 6  Qual melhor site para aprender sobre RobotFram...
# 7  Qual a Melhor faculdade e plataforama que eu p...
#
#                                             Conteudo
# 0  Para verificar se a instalação do Python foi b...
# 1  Instalar o Robot Framework com pip é simples:p...
# 2  para acessa sua biblioteca voce precisa acessa...
# 3  Tanto as palavras-chave do usuário quanto as p...
# 4  Robot Framework é uma estrutura de automação d...
# 5  A estrutura do arquivo de saída JSON está docu...
# 6  acesse alura, garanto que você vai aprenser mu...
# 7  esta é muito facil acess Fiap e Aluera voce va...

# %%
model = "models/embedding-001"

# %%
def embed_fn(title, text):
  return genai.embed_content(model=model,
                                 content=text,
                                 title=title,
                                 task_type="RETRIEVAL_DOCUMENT")["embedding"]

# %%
df["Embeddings"] = df.apply(lambda row: embed_fn(row["Titulo"], row["Conteudo"]), axis=1)
df
# Out:
#                                               Titulo  \
# 0                              como instalar python
# 1                                como instalar robot
# 2  como eu consigo ver as bibliotecas do robotfra...
# 3          como usar palavras chaves roobotframework
# 4                            o que é robot framework
# 5  como usar arquivo de saida json no robotframework
# 6  Qual melhor site para aprender sobre RobotFram...
# 7  Qual a Melhor faculdade e plataforama que eu p...
#
#                                             Conteudo  \
# 0  Para verificar se a instalação do Python foi b...
# 1  Instalar o Robot Framework com pip é simples:p...
# 2  para acessa sua biblioteca voce precisa acessa...
# 3  Tanto as palavras-chave do usuário quanto as p...
# 4  Robot Framework é uma estrutura de automação d...
# 5  A estrutura do arquivo de saída JSON está docu...
# 6  acesse alura, garanto que você vai aprenser mu...
# 7  esta é muito facil acess Fiap e Aluera voce va...
#
# ...

# %%
def gerar_e_buscar_consulta(consulta, base, model):
  embedding_da_consulta = genai.embed_content(model=model,
                                 content=consulta,
                                 task_type="RETRIEVAL_QUERY")["embedding"]

  produtos_escalares = np.dot(np.stack(df["Embeddings"]), embedding_da_consulta)

  indice = np.argmax(produtos_escalares)
  return df.iloc[indice]["Conteudo"]

# %%
consulta = "Qual a Melhor faculdade e plataforama que eu possa estudar e fazer cursos de IA"

trecho = gerar_e_buscar_consulta(consulta, df, model)
print(trecho)
# Out:
# esta é muito facil acess Fiap e Aluera voce vai ser dar muito bem  segue os links, https://www.alura.com.br/, https://www.fiap.com.br/

# %%
GenerationConfig = {
    "temperatures": 0.1,
    "candidate_count":1,

}

# %%
prompt = f"onde posso estudar sobre IA {trecho}"

model_2 = genai.GenerativeModel("gemini-1.0-pro")
response = model_2.generate_content(prompt)
print(response.text)
# Out:
# Claro, existem vários recursos online onde você pode aprender sobre Inteligência Artificial (IA), incluindo:
#
# **Plataformas de Cursos Online**
#
# * **Alura:** https://www.alura.com.br/
# * **FIAP:** https://www.fiap.com.br/
# * **Coursera:** https://www.coursera.org/browse/artificial-intelligence
# * **edX:** https://www.edx.org/learn/artificial-intelligence
# * **Udemy:** https://www.udemy.com/topic/ai/
#
# **Recursos Gratuitos Online**
#
# * **Google AI Education:** https://ai.google/education/
# * **MIT OpenCourseWare:** https://ocw.mit.edu/courses/find-by-topic/#cat=engineering&subcat=electrical-engineering-and-computer-science&spec=artificial-intelligence
# * **IBM Developer:** https://developer.ibm.com/technologies/artificial-intelligence/
# * **Microsoft AI:** https://docs.microsoft.com/en-us/azure/ai/
# * **NVIDIA Developer:** https://developer.nvidia.com/ai
#
# **Outros Recursos**
#
# ...
